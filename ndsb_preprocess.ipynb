# %%
import os
import numpy as np
import dicom
from scipy.misc import imresize
import random

# %%
directory = os.getcwd()
resize = True
img_shape = (128,128)

# %%
'''Loading train labels'''
def load_labels(filename):
    # load the train labels and create a disctionary with patient id as a key and Systole and Diastole vols as values
    labels_tr = np.loadtxt(os.path.join(directory, filename), delimiter=",", skiprows=1)
    tr_map = {}
    for l in labels_tr:
        tr_map[int(l[0])] = [float(l[1]), float(l[2])]
    
    return tr_map

# %%
def image_resize(img):
    '''Resize the image as per img_shape. Crop if required from the center'''
    if img.shape[0] < img.shape[1]:
        img = img.T
    short_side = min(img.shape[:2])
    '''Crop from center'''
    y = int(img.shape[0] - short_side/2)
    x = int(img.shape[1] - short_side/2)
    cropped_img = img[y:y+short_side, x:x+short_side]
    img = imresize(cropped_img, img_shape)
    
    return img

# %%
def load_images(folder):
    ''' Loads all the dicom images in the given folder'''
    path, patient_folders, _ = next(os.walk(os.path.join(directory,folder)))
    patient_folders = [int(p) for p in patient_folders ]
    #patient_folders = random.sample(patient_folders, 100)
    study_images = {}
    study_ids = set()
    images = []
    slice_images = []
    s_count = 0
    for subdir in patient_folders:
        subdir = str(subdir)
        img_path, subdirs,_ = next(os.walk(os.path.join(path, subdir)))
        if len(subdirs) == 1:
            img_path, slices,_ = next(os.walk(os.path.join(path, subdir, subdirs[0])))
        else:
            slices = subdirs

        print("loading images from folder %s of %s" %(subdir, folder))

        for s in slices:
            if "sax" in s:
                files = next(os.walk(os.path.join(img_path, s)))[2]
                img_count = len([file for file in files if file.endswith(".dcm")])
                for file in files:

                    if file.endswith(".dcm"):
                        file_path = os.path.join(img_path, s, file)
                        image = dicom.read_file(file_path)
                        try:
                            image = image.pixel_array.astype(float)
                            image /= np.max(image) #scaling
                            if resize:
                                image = image_resize(image)

                            images.append(image)
                        except ValueError as e:
                            print("error in making array from %s file of %s/%s"%(file,subdir,s))
                        
                        

                        if len(images) == img_count:
                            if img_count != 30:
                                x=0
                                try:
                                    while len(images) < 30:
                                        images.append(images[x])
                                        x += 1
                                    if len(images) > 30:
                                        images = images[0:30]
                                except IndexError:
                                    pass

                            slice_images.append(np.array(images))
                            images = []
                            

        print("%d sax foldes" %len(slice_images))
        study_images[subdir] = np.array(slice_images)
        study_ids.add(subdir)
        slice_images = []

    return list(study_ids), study_images

# %%
'''Load train and validation images. Resize and check if every slice has got 30 images'''

def train_npy(folder):
    print("Writing npy file for train images...")
    ids, images = load_images(folder)
    #ids, images = load_images()
    f = folder + ".csv"
    labels = load_labels(f)
    X = []
    y = []
    for pid in ids:
        study_images = images[pid]
        output = labels[int(pid)]
        
        for i in range(study_images.shape[0]):
            X.append(study_images[i,:,:,:])
            y.append(output)
    #Create data and labels arrays to save as .npy file
    
    X = np.array(X, dtype=np.uint8)
    y = np.array(y)
    
    return X,y

# %%
X1,y1 = train_npy("train")
X2,y2 = train_npy("validate")

X = np.concatenate((X1,X2))
y = np.concatenate((y1,y2))

np.save("X_trval.npy", X)
np.save("y_trval.npy", y)
print("Done saving processed train and validation images and labels")

# %%
'''Load validation images. Resize and check if every slice has got 30 images'''

def validation_npy():
    print("Writing npy file for validation images...")
    ids, images = load_images("validate")
    #labels = load_labels()
    X = []
    study_ids = []
    #y = []
    for pid in ids:
        study_images = images[pid]

        for i in range(study_images.shape[0]):
            X.append(study_images[i,:,:,:])
            study_ids.append(pid)

    #Create data and labels arrays to save as .npy file

    X = np.array(X, dtype=np.uint8)

    np.save('X_validation.npy', X)
    np.save('ids_validate.npy', study_ids)

    print("Done saving processed validation images")

# %%
'''Load test images. Resize and check if every slice has got 30 images'''

def test_npy():
    print("Writing npy file for validation images...")
    ids, images = load_images("test")
    #labels = load_labels()
    X = []
    study_ids = []
    #y = []
    for pid in ids:
        study_images = images[pid]

        for i in range(study_images.shape[0]):
            X.append(study_images[i,:,:,:])
            study_ids.append(pid)

    #Create data and labels arrays to save as .npy file

    X = np.array(X, dtype=np.uint8)

    np.save('X_test.npy', X)
    np.save('ids_test.npy', study_ids)

    print("Done saving processed images of test folder")

# %%
#Creates target values for validation images.
ids=np.load("ids_validate.npy")
labels = np.loadtxt("validate.csv", delimiter=",", skiprows=1)
map_val = {}
y_val = []
for l in labels:
    map_val[int(l[0])] = [float(l[1]), float(l[2])]

for i in ids:
    out = map_val[int(i)]
    y_val.append(out)

# %%
#Combine train and validate images
a = np.load("X_train.npy")
b = np.load("X_validation.npy")
c= np.concatenate((a,b))

#Combine train and validate labels
d=np.load("y_train.npy")
y_val = np.array(y_val)
y_trval = np.concatenate((d,y_val))

#Save them as numpy array
np.save("X_trval.npy", c)
np.save("y_trval.npy", y_trval)

# %%
test_npy()
# Out:
# Writing npy file for validation images...
# loading images from folder 1000 of test
# 9 sax foldes
# loading images from folder 1001 of test
# 10 sax foldes
# loading images from folder 1002 of test
# 10 sax foldes
# loading images from folder 1003 of test
# 11 sax foldes
# loading images from folder 1004 of test
# 11 sax foldes
# loading images from folder 1005 of test
# 9 sax foldes
# loading images from folder 1006 of test
# 10 sax foldes
# loading images from folder 1007 of test
# 11 sax foldes
# loading images from folder 1008 of test
# 9 sax foldes
# loading images from folder 1009 of test
# 9 sax foldes
# loading images from folder 1010 of test
# 11 sax foldes
# loading images from folder 1011 of test
# 11 sax foldes
# loading images from folder 1012 of test
# 12 sax foldes
# loading images from folder 1013 of test
# 12 sax foldes
# loading images from folder 1014 of test
# 9 sax foldes
# loading images from folder 1015 of test
# 10 sax foldes
# loading images from folder 1016 of test
# 10 sax foldes
# loading images from folder 1017 of test
# 11 sax foldes
# loading images from folder 1018 of test
# 11 sax foldes
# loading images from folder 1019 of test
# 11 sax foldes
# loading images from folder 1020 of test
# 11 sax foldes
# loading images from folder 1021 of test
# 9 sax foldes
# loading images from folder 1022 of test
# 10 sax foldes
# loading images from folder 1023 of test
# 11 sax foldes
# loading images from folder 1024 of test
# 9 sax foldes
# loading images from folder 1025 of test
# 10 sax foldes
# loading images from folder 1026 of test
# 10 sax foldes
# loading images from folder 1027 of test
# 13 sax foldes
# loading images from folder 1028 of test
# 11 sax foldes
# loading images from folder 1029 of test
# 14 sax foldes
# loading images from folder 1030 of test
# 11 sax foldes
# loading images from folder 1031 of test
# 13 sax foldes
# loading images from folder 1032 of test
# 12 sax foldes
# loading images from folder 1033 of test
# 10 sax foldes
# loading images from folder 1034 of test
# 10 sax foldes
# loading images from folder 1035 of test
# 10 sax foldes
# loading images from folder 1036 of test
# 10 sax foldes
# loading images from folder 1037 of test
# 10 sax foldes
# loading images from folder 1038 of test
# 9 sax foldes
# loading images from folder 1039 of test
# 9 sax foldes
# loading images from folder 1040 of test
# 11 sax foldes
# loading images from folder 1041 of test
# 12 sax foldes
# loading images from folder 1042 of test
# 11 sax foldes
# loading images from folder 1043 of test
# 9 sax foldes
# loading images from folder 1044 of test
# 10 sax foldes
# loading images from folder 1045 of test
# 10 sax foldes
# loading images from folder 1046 of test
# 10 sax foldes
# loading images from folder 1047 of test
# 13 sax foldes
# loading images from folder 1048 of test
# 11 sax foldes
# loading images from folder 1049 of test
# 12 sax foldes
# loading images from folder 1050 of test
# 11 sax foldes
# loading images from folder 1051 of test
# 12 sax foldes
# loading images from folder 1052 of test
# 9 sax foldes
# loading images from folder 1053 of test
# 10 sax foldes
# loading images from folder 1054 of test
# 10 sax foldes
# loading images from folder 1055 of test
# 12 sax foldes
# loading images from folder 1056 of test
# 11 sax foldes
# loading images from folder 1057 of test
# 9 sax foldes
# loading images from folder 1058 of test
# 10 sax foldes
# loading images from folder 1059 of test
# 10 sax foldes
# loading images from folder 1060 of test
# 10 sax foldes
# loading images from folder 1061 of test
# 10 sax foldes
# loading images from folder 1062 of test
# 14 sax foldes
# loading images from folder 1063 of test
# 11 sax foldes
# loading images from folder 1064 of test
# 11 sax foldes
# loading images from folder 1065 of test
# 11 sax foldes
# loading images from folder 1066 of test
# 9 sax foldes
# loading images from folder 1067 of test
# 10 sax foldes
# loading images from folder 1068 of test
# 11 sax foldes
# loading images from folder 1069 of test
# 11 sax foldes
# loading images from folder 1070 of test
# 11 sax foldes
# loading images from folder 1071 of test
# 11 sax foldes
# loading images from folder 1072 of test
# 10 sax foldes
# loading images from folder 1073 of test
# 11 sax foldes
# loading images from folder 1074 of test
# 15 sax foldes
# loading images from folder 1075 of test
# 9 sax foldes
# loading images from folder 1076 of test
# 13 sax foldes
# loading images from folder 1077 of test
# 9 sax foldes
# loading images from folder 1078 of test
# 11 sax foldes
# loading images from folder 1079 of test
# 15 sax foldes
# loading images from folder 1080 of test
# 11 sax foldes
# loading images from folder 1081 of test
# 11 sax foldes
# loading images from folder 1082 of test
# 3 sax foldes
# loading images from folder 1083 of test
# 9 sax foldes
# loading images from folder 1084 of test
# 12 sax foldes
# loading images from folder 1085 of test
# 11 sax foldes
# loading images from folder 1086 of test
# 9 sax foldes
# loading images from folder 1087 of test
# 9 sax foldes
# loading images from folder 1088 of test
# 11 sax foldes
# loading images from folder 1089 of test
# 11 sax foldes
# loading images from folder 1090 of test
# 10 sax foldes
# loading images from folder 1091 of test
# 9 sax foldes
# loading images from folder 1092 of test
# 11 sax foldes
# loading images from folder 1093 of test
# 9 sax foldes
# loading images from folder 1094 of test
# 11 sax foldes
# loading images from folder 1095 of test
# 14 sax foldes
# loading images from folder 1096 of test
# 9 sax foldes
# loading images from folder 1097 of test
# 9 sax foldes
# loading images from folder 1098 of test
# 8 sax foldes
# loading images from folder 1099 of test
# 9 sax foldes
# loading images from folder 1100 of test
# 9 sax foldes
# loading images from folder 1101 of test
# 11 sax foldes
# loading images from folder 1102 of test
# 9 sax foldes
# loading images from folder 1103 of test
# 12 sax foldes
# loading images from folder 1104 of test
# 11 sax foldes
# loading images from folder 1105 of test
# 12 sax foldes
# loading images from folder 1106 of test
# 9 sax foldes
# loading images from folder 1107 of test
# 8 sax foldes
# loading images from folder 1108 of test
# 9 sax foldes
# loading images from folder 1109 of test
# 10 sax foldes
# loading images from folder 1110 of test
# 8 sax foldes
# loading images from folder 1111 of test
# 12 sax foldes
# loading images from folder 1112 of test
# 12 sax foldes
# loading images from folder 1113 of test
# 8 sax foldes
# loading images from folder 1114 of test
# 12 sax foldes
# loading images from folder 1115 of test
# 11 sax foldes
# loading images from folder 1116 of test
# 11 sax foldes
# loading images from folder 1117 of test
# 12 sax foldes
# loading images from folder 1118 of test
# 13 sax foldes
# loading images from folder 1119 of test
# 11 sax foldes
# loading images from folder 1120 of test
# 12 sax foldes
# loading images from folder 1121 of test
# 9 sax foldes
# loading images from folder 1122 of test
# 10 sax foldes
# loading images from folder 1123 of test
# 11 sax foldes
# loading images from folder 1124 of test
# 10 sax foldes
# loading images from folder 1125 of test
# 9 sax foldes
# loading images from folder 1126 of test
# 11 sax foldes
# loading images from folder 1127 of test
# 11 sax foldes
# loading images from folder 1128 of test
# 11 sax foldes
# loading images from folder 1129 of test
# 11 sax foldes
# loading images from folder 1130 of test
# 10 sax foldes
# loading images from folder 1131 of test
# 10 sax foldes
# loading images from folder 1132 of test
# 12 sax foldes
# loading images from folder 1133 of test
# 12 sax foldes
# loading images from folder 1134 of test
# 11 sax foldes
# loading images from folder 1135 of test
# 11 sax foldes
# loading images from folder 1136 of test
# 11 sax foldes
# loading images from folder 1137 of test
# 13 sax foldes
# loading images from folder 1138 of test
# 11 sax foldes
# loading images from folder 1139 of test
# 9 sax foldes
# loading images from folder 1140 of test
# 11 sax foldes
# loading images from folder 701 of test
# 11 sax foldes
# loading images from folder 702 of test
# 11 sax foldes
# loading images from folder 703 of test
# 9 sax foldes
# loading images from folder 704 of test
# 10 sax foldes
# loading images from folder 705 of test
# 9 sax foldes
# loading images from folder 706 of test
# 9 sax foldes
# loading images from folder 707 of test
# 11 sax foldes
# loading images from folder 708 of test
# 15 sax foldes
# loading images from folder 709 of test
# 12 sax foldes
# loading images from folder 710 of test
# 11 sax foldes
# loading images from folder 711 of test
# 11 sax foldes
# loading images from folder 712 of test
# 10 sax foldes
# loading images from folder 713 of test
# 11 sax foldes
# loading images from folder 714 of test
# 10 sax foldes
# loading images from folder 715 of test
# 9 sax foldes
# loading images from folder 716 of test
# 9 sax foldes
# loading images from folder 717 of test
# 10 sax foldes
# loading images from folder 718 of test
# 11 sax foldes
# loading images from folder 719 of test
# 10 sax foldes
# loading images from folder 720 of test
# 11 sax foldes
# loading images from folder 721 of test
# 12 sax foldes
# loading images from folder 722 of test
# 9 sax foldes
# loading images from folder 723 of test
# 13 sax foldes
# loading images from folder 724 of test
# 11 sax foldes
# loading images from folder 725 of test
# 11 sax foldes
# loading images from folder 726 of test
# 11 sax foldes
# loading images from folder 727 of test
# 11 sax foldes
# loading images from folder 728 of test
# 11 sax foldes
# loading images from folder 729 of test
# 13 sax foldes
# loading images from folder 730 of test
# 11 sax foldes
# loading images from folder 731 of test
# 2 sax foldes
# loading images from folder 732 of test
# 9 sax foldes
# loading images from folder 733 of test
# 9 sax foldes
# loading images from folder 734 of test
# 11 sax foldes
# loading images from folder 735 of test
# 9 sax foldes
# loading images from folder 736 of test
# 9 sax foldes
# loading images from folder 737 of test
# 9 sax foldes
# loading images from folder 738 of test
# 11 sax foldes
# loading images from folder 739 of test
# 12 sax foldes
# loading images from folder 740 of test
# 12 sax foldes
# loading images from folder 741 of test
# 9 sax foldes
# loading images from folder 742 of test
# 15 sax foldes
# loading images from folder 743 of test
# 12 sax foldes
# loading images from folder 744 of test
# 9 sax foldes
# loading images from folder 745 of test
# 10 sax foldes
# loading images from folder 746 of test
# 14 sax foldes
# loading images from folder 747 of test
# 11 sax foldes
# loading images from folder 748 of test
# 11 sax foldes
# loading images from folder 749 of test
# 11 sax foldes
# loading images from folder 750 of test
# 11 sax foldes
# loading images from folder 751 of test
# 9 sax foldes
# loading images from folder 752 of test
# 11 sax foldes
# loading images from folder 753 of test
# 11 sax foldes
# loading images from folder 754 of test
# 10 sax foldes
# loading images from folder 755 of test
# 15 sax foldes
# loading images from folder 756 of test
# 14 sax foldes
# loading images from folder 757 of test
# 13 sax foldes
# loading images from folder 758 of test
# 10 sax foldes
# loading images from folder 759 of test
# 11 sax foldes
# loading images from folder 760 of test
# 4 sax foldes
# loading images from folder 761 of test
# 10 sax foldes
# loading images from folder 762 of test
# 10 sax foldes
# loading images from folder 763 of test
# 8 sax foldes
# loading images from folder 764 of test
# 9 sax foldes
# loading images from folder 765 of test
# 10 sax foldes
# loading images from folder 766 of test
# 9 sax foldes
# loading images from folder 767 of test
# 10 sax foldes
# loading images from folder 768 of test
# 9 sax foldes
# loading images from folder 769 of test
# 11 sax foldes
# loading images from folder 770 of test
# 10 sax foldes
# loading images from folder 771 of test
# 9 sax foldes
# loading images from folder 772 of test
# 12 sax foldes
# loading images from folder 773 of test
# 11 sax foldes
# loading images from folder 774 of test
# 10 sax foldes
# loading images from folder 775 of test
# 1 sax foldes
# loading images from folder 776 of test
# 11 sax foldes
# loading images from folder 777 of test
# 9 sax foldes
# loading images from folder 778 of test
# 11 sax foldes
# loading images from folder 779 of test
# 10 sax foldes
# loading images from folder 780 of test
# 13 sax foldes
# loading images from folder 781 of test
# 9 sax foldes
# loading images from folder 782 of test
# 8 sax foldes
# loading images from folder 783 of test
# 8 sax foldes
# loading images from folder 784 of test
# 11 sax foldes
# loading images from folder 785 of test
# 10 sax foldes
# loading images from folder 786 of test
# 13 sax foldes
# loading images from folder 787 of test
# 10 sax foldes
# loading images from folder 788 of test
# 10 sax foldes
# loading images from folder 789 of test
# 13 sax foldes
# loading images from folder 790 of test
# 11 sax foldes
# loading images from folder 791 of test
# 11 sax foldes
# loading images from folder 792 of test
# 10 sax foldes
# loading images from folder 793 of test
# 14 sax foldes
# loading images from folder 794 of test
# 9 sax foldes
# loading images from folder 795 of test
# 10 sax foldes
# loading images from folder 796 of test
# 11 sax foldes
# loading images from folder 797 of test
# 11 sax foldes
# loading images from folder 798 of test
# 10 sax foldes
# loading images from folder 799 of test
# 10 sax foldes
# loading images from folder 800 of test
# 10 sax foldes
# loading images from folder 801 of test
# 12 sax foldes
# loading images from folder 802 of test
# 8 sax foldes
# loading images from folder 803 of test
# 10 sax foldes
# loading images from folder 804 of test
# 14 sax foldes
# loading images from folder 805 of test
# 9 sax foldes
# loading images from folder 806 of test
# 12 sax foldes
# loading images from folder 807 of test
# 9 sax foldes
# loading images from folder 808 of test
# 11 sax foldes
# loading images from folder 809 of test
# 12 sax foldes
# loading images from folder 810 of test
# 11 sax foldes
# loading images from folder 811 of test
# 10 sax foldes
# loading images from folder 812 of test
# 10 sax foldes
# loading images from folder 813 of test
# 11 sax foldes
# loading images from folder 814 of test
# 15 sax foldes
# loading images from folder 815 of test
# 13 sax foldes
# loading images from folder 816 of test
# 12 sax foldes
# loading images from folder 817 of test
# 11 sax foldes
# loading images from folder 818 of test
# 10 sax foldes
# loading images from folder 819 of test
# 9 sax foldes
# loading images from folder 820 of test
# 10 sax foldes
# loading images from folder 821 of test
# 10 sax foldes
# loading images from folder 822 of test
# 9 sax foldes
# loading images from folder 823 of test
# 11 sax foldes
# loading images from folder 824 of test
# 10 sax foldes
# loading images from folder 825 of test
# 10 sax foldes
# loading images from folder 826 of test
# 10 sax foldes
# loading images from folder 827 of test
# 12 sax foldes
# loading images from folder 828 of test
# 11 sax foldes
# loading images from folder 829 of test
# 11 sax foldes
# loading images from folder 830 of test
# 13 sax foldes
# loading images from folder 831 of test
# 17 sax foldes
# loading images from folder 832 of test
# 9 sax foldes
# loading images from folder 833 of test
# 11 sax foldes
# loading images from folder 834 of test
# 1 sax foldes
# loading images from folder 835 of test
# 13 sax foldes
# loading images from folder 836 of test
# 10 sax foldes
# loading images from folder 837 of test
# 12 sax foldes
# loading images from folder 838 of test
# 9 sax foldes
# loading images from folder 839 of test
# 11 sax foldes
# loading images from folder 840 of test
# 9 sax foldes
# loading images from folder 841 of test
# 9 sax foldes
# loading images from folder 842 of test
# 12 sax foldes
# loading images from folder 843 of test
# 11 sax foldes
# loading images from folder 844 of test
# 13 sax foldes
# loading images from folder 845 of test
# 11 sax foldes
# loading images from folder 846 of test
# 12 sax foldes
# loading images from folder 847 of test
# 14 sax foldes
# loading images from folder 848 of test
# 11 sax foldes
# loading images from folder 849 of test
# 12 sax foldes
# loading images from folder 850 of test
# 11 sax foldes
# loading images from folder 851 of test
# 9 sax foldes
# loading images from folder 852 of test
# 9 sax foldes
# loading images from folder 853 of test
# 11 sax foldes
# loading images from folder 854 of test
# 9 sax foldes
# loading images from folder 855 of test
# 8 sax foldes
# loading images from folder 856 of test
# 12 sax foldes
# loading images from folder 857 of test
# 15 sax foldes
# loading images from folder 858 of test
# 11 sax foldes
# loading images from folder 859 of test
# 10 sax foldes
# loading images from folder 860 of test
# 9 sax foldes
# loading images from folder 861 of test
# 10 sax foldes
# loading images from folder 862 of test
# 9 sax foldes
# loading images from folder 863 of test
# 13 sax foldes
# loading images from folder 864 of test
# 8 sax foldes
# loading images from folder 865 of test
# 10 sax foldes
# loading images from folder 866 of test
# 12 sax foldes
# loading images from folder 867 of test
# 10 sax foldes
# loading images from folder 868 of test
# 10 sax foldes
# loading images from folder 869 of test
# 11 sax foldes
# loading images from folder 870 of test
# 25 sax foldes
# loading images from folder 871 of test
# 10 sax foldes
# loading images from folder 872 of test
# 11 sax foldes
# loading images from folder 873 of test
# 10 sax foldes
# loading images from folder 874 of test
# 11 sax foldes
# loading images from folder 875 of test
# 11 sax foldes
# loading images from folder 876 of test
# 9 sax foldes
# loading images from folder 877 of test
# 10 sax foldes
# loading images from folder 878 of test
# 9 sax foldes
# loading images from folder 879 of test
# 10 sax foldes
# loading images from folder 880 of test
# 11 sax foldes
# loading images from folder 881 of test
# 10 sax foldes
# loading images from folder 882 of test
# 9 sax foldes
# loading images from folder 883 of test
# 13 sax foldes
# loading images from folder 884 of test
# 11 sax foldes
# loading images from folder 885 of test
# 10 sax foldes
# loading images from folder 886 of test
# 8 sax foldes
# loading images from folder 887 of test
# 11 sax foldes
# loading images from folder 888 of test
# 1 sax foldes
# loading images from folder 889 of test
# 10 sax foldes
# loading images from folder 890 of test
# 12 sax foldes
# loading images from folder 891 of test
# 11 sax foldes
# loading images from folder 892 of test
# 10 sax foldes
# loading images from folder 893 of test
# 9 sax foldes
# loading images from folder 894 of test
# 13 sax foldes
# loading images from folder 895 of test
# 10 sax foldes
# loading images from folder 896 of test
# 12 sax foldes
# loading images from folder 897 of test
# 12 sax foldes
# loading images from folder 898 of test
# 11 sax foldes
# loading images from folder 899 of test
# 9 sax foldes
# loading images from folder 900 of test
# 10 sax foldes
# loading images from folder 901 of test
# 11 sax foldes
# loading images from folder 902 of test
# 13 sax foldes
# loading images from folder 903 of test
# 11 sax foldes
# loading images from folder 904 of test
# 10 sax foldes
# loading images from folder 905 of test
# 11 sax foldes
# loading images from folder 906 of test
# 10 sax foldes
# loading images from folder 907 of test
# 9 sax foldes
# loading images from folder 908 of test
# 11 sax foldes
# loading images from folder 909 of test
# 10 sax foldes
# loading images from folder 910 of test
# 8 sax foldes
# loading images from folder 911 of test
# 9 sax foldes
# loading images from folder 912 of test
# 10 sax foldes
# loading images from folder 913 of test
# 10 sax foldes
# loading images from folder 914 of test
# 11 sax foldes
# loading images from folder 915 of test
# 9 sax foldes
# loading images from folder 916 of test
# 11 sax foldes
# loading images from folder 917 of test
# 10 sax foldes
# loading images from folder 918 of test
# 11 sax foldes
# loading images from folder 919 of test
# 11 sax foldes
# loading images from folder 920 of test
# 12 sax foldes
# loading images from folder 921 of test
# 12 sax foldes
# loading images from folder 922 of test
# 9 sax foldes
# loading images from folder 923 of test
# 9 sax foldes
# loading images from folder 924 of test
# 11 sax foldes
# loading images from folder 925 of test
# 9 sax foldes
# loading images from folder 926 of test
# 11 sax foldes
# loading images from folder 927 of test
# 10 sax foldes
# loading images from folder 928 of test
# 8 sax foldes
# loading images from folder 929 of test
# 11 sax foldes
# loading images from folder 930 of test
# 9 sax foldes
# loading images from folder 931 of test
# 9 sax foldes
# loading images from folder 932 of test
# 10 sax foldes
# loading images from folder 933 of test
# 10 sax foldes
# loading images from folder 934 of test
# 9 sax foldes
# loading images from folder 935 of test
# 8 sax foldes
# loading images from folder 936 of test
# 9 sax foldes
# loading images from folder 937 of test
# 11 sax foldes
# loading images from folder 938 of test
# 11 sax foldes
# loading images from folder 939 of test
# 9 sax foldes
# loading images from folder 940 of test
# 10 sax foldes
# loading images from folder 941 of test
# 12 sax foldes
# loading images from folder 942 of test
# 14 sax foldes
# loading images from folder 943 of test
# 9 sax foldes
# loading images from folder 944 of test
# 12 sax foldes
# loading images from folder 945 of test
# 10 sax foldes
# loading images from folder 946 of test
# 11 sax foldes
# loading images from folder 947 of test
# 11 sax foldes
# loading images from folder 948 of test
# 10 sax foldes
# loading images from folder 949 of test
# 11 sax foldes
# loading images from folder 950 of test
# 11 sax foldes
# loading images from folder 951 of test
# 12 sax foldes
# loading images from folder 952 of test
# 16 sax foldes
# loading images from folder 953 of test
# 11 sax foldes
# loading images from folder 954 of test
# 12 sax foldes
# loading images from folder 955 of test
# 10 sax foldes
# loading images from folder 956 of test
# 10 sax foldes
# loading images from folder 957 of test
# 11 sax foldes
# loading images from folder 958 of test
# 11 sax foldes
# loading images from folder 959 of test
# 10 sax foldes
# loading images from folder 960 of test
# 13 sax foldes
# loading images from folder 961 of test
# 10 sax foldes
# loading images from folder 962 of test
# 9 sax foldes
# loading images from folder 963 of test
# 12 sax foldes
# loading images from folder 964 of test
# 9 sax foldes
# loading images from folder 965 of test
# 11 sax foldes
# loading images from folder 966 of test
# 9 sax foldes
# loading images from folder 967 of test
# 11 sax foldes
# loading images from folder 968 of test
# 9 sax foldes
# loading images from folder 969 of test
# 11 sax foldes
# loading images from folder 970 of test
# 9 sax foldes
# loading images from folder 971 of test
# 11 sax foldes
# loading images from folder 972 of test
# 9 sax foldes
# loading images from folder 973 of test
# 8 sax foldes
# loading images from folder 974 of test
# 10 sax foldes
# loading images from folder 975 of test
# 11 sax foldes
# loading images from folder 976 of test
# 18 sax foldes
# loading images from folder 977 of test
# 12 sax foldes
# loading images from folder 978 of test
# 11 sax foldes
# loading images from folder 979 of test
# 13 sax foldes
# loading images from folder 980 of test
# 10 sax foldes
# loading images from folder 981 of test
# 9 sax foldes
# loading images from folder 982 of test
# 10 sax foldes
# loading images from folder 983 of test
# 10 sax foldes
# loading images from folder 984 of test
# 11 sax foldes
# loading images from folder 985 of test
# 14 sax foldes
# loading images from folder 986 of test
# 12 sax foldes
# loading images from folder 987 of test
# 9 sax foldes
# loading images from folder 988 of test
# 8 sax foldes
# loading images from folder 989 of test
# 11 sax foldes
# loading images from folder 990 of test
# 13 sax foldes
# loading images from folder 991 of test
# 11 sax foldes
# loading images from folder 992 of test
# 12 sax foldes
# loading images from folder 993 of test
# 9 sax foldes
# loading images from folder 994 of test
# 13 sax foldes
# loading images from folder 995 of test
# 11 sax foldes
# loading images from folder 996 of test
# 11 sax foldes
# loading images from folder 997 of test
# 13 sax foldes
# loading images from folder 998 of test
# 11 sax foldes
# loading images from folder 999 of test
# 10 sax foldes
# Done saving processed images of test folder
